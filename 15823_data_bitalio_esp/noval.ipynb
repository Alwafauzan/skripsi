# %%
import pandas as pd
# 1. pengambilan data
# 2. preprocessing
# band pass , low pass , fft , high pass,
# 3. feature extraction

# 4. klasifikasi/regresi/klaster

# %%
noval_ppg = pd.read_csv('noval_ppg.csv',sep=';')
noval_emg = pd.read_csv('noval_emg.csv',sep=';')

# %%
noval_ppg[5000:6000].plot()
# Out:
# <Axes: >

# %%
noval_emg.plot()
# Out:
# <Axes: >
