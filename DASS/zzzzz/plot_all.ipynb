# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
import pyfirmata

pyfirmata.Arduino()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# f:\repo\skripsi\DASS\plot_all.ipynb Cell 2 line 3
#       <a href='vscode-notebook-cell:/f%3A/repo/skripsi/DASS/plot_all.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> import pyfirmata
# ----> <a href='vscode-notebook-cell:/f%3A/repo/skripsi/DASS/plot_all.ipynb#W2sZmlsZQ%3D%3D?line=2'>3</a> pyfirmata.Arduino()
#
# AttributeError: module 'pyfirmata' has no attribute 'Arduino'

# %%
fig, axes = plt.subplots(nrows=16, ncols=1)

amel_tkr['r'].plot(ax=axes[0], figsize=(10,15), title='amel_tkr')
andika_tkr['r'].plot(ax=axes[1], figsize=(10,15), title='andika_tkr')
dhea_tkr['r'].plot(ax=axes[2], figsize=(10,15), title='dhea_tkr')
elya_tkr['r'].plot(ax=axes[3], figsize=(10,15), title='elya_tkr')
fauzi_tkr['r'].plot(ax=axes[4], figsize=(10,15), title='fauzi_tkr')
iam_tkr['r'].plot(ax=axes[5], figsize=(10,15), title='iam_tkr')
kanwa_tkr['r'].plot(ax=axes[6], figsize=(10,15), title='kanwa_tkr')
nanda_tkr['r'].plot(ax=axes[7], figsize=(10,15), title='nanda_tkr')
nandakkn_tkr['r'].plot(ax=axes[8], figsize=(10,15), title='nandakkn_tkr')
nopen_tkr['r'].plot(ax=axes[9], figsize=(10,15), title='nopen_tkr')
nopen_tkr2['r'].plot(ax=axes[10], figsize=(10,15), title='nopen_tkr2')
pradja_tkr['r'].plot(ax=axes[11], figsize=(10,15), title='pradja_tkr')
raihan_tkr['r'].plot(ax=axes[12], figsize=(10,15), title='raihan_tkr')
rico_tkr['r'].plot(ax=axes[13], figsize=(10,15), title='rico_tkr')
silvia_tkr['r'].plot(ax=axes[14], figsize=(10,15), title='silvia_tkr')
visky_tkr['r'].plot(ax=axes[15], figsize=(10,15), title='visky_tkr')
# Out:
# <Axes: title={'center': 'visky_tkr'}>
