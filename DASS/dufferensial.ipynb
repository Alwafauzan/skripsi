# %%
import neurokit2 as nk
import pandas as pd

# %%
amel = pd.read_csv('amel_tkr.csv',sep = ';')
amel.columns = ["ir","waktu"]
amel = amel[(amel.waktu <= 20)]

# %%
ameldiff1 = amel.diff()
ameldiff2 = ameldiff1.diff()

# %%
amel.plot()
# Out:
# <Axes: >

# %%
ameldiff1.plot(figsize = (20,5))
# ameldiff1[1:len(ameldiff1)]
# Out:
# <Axes: >

# %%
ameldiff2.plot(figsize=(20,5))
# Out:
# <Axes: >

# %%
# ppg_amel = nk.ppg_clean(amel[['ir']], sampling_rate=200)
# peaks_amel = nk.ppg_findpeaks(ppg_amel,sampling_rate=35,show=False)

ppg_ameldiff1 = nk.ppg_clean(ameldiff1['ir'][1:len(ameldiff1)], sampling_rate=200)
peaks_ameldiff1 = nk.ppg_findpeaks(ppg_ameldiff1,sampling_rate=100,show=True)

# ppg_ameldiff2 = nk.ppg_clean(ameldiff2['ir'][2:len(ameldiff2)], sampling_rate=200)
# peaks_ameldiff2 = nk.ppg_findpeaks(ppg_ameldiff2,sampling_rate=35,show=True)
