# %%
import pandas as pd

# %%
url = 'https://docs.google.com/spreadsheets/d/1ykx1bzPqkk4N1w2Cjr4muc2czy4p-BkGR5XXBlwKywg/edit?usp=sharing'
url_split = url.split('/')[-2]
url_split
pd.read_excel('https://drive.google.com/uc?id=12ZYOKcsbHOjwbKd93AIgCrXTdHTShiRa')
# https://drive.google.com/uc?id=1SCz6Wh3Xgd6KguSRXAYrR-ph6tU3vGPE
# https://drive.google.com/uc?id=1ykx1bzPqkk4N1w2Cjr4muc2czy4p-BkGR5XXBlwKywg
# https://drive.google.com/uc?id=12ZYOKcsbHOjwbKd93AIgCrXTdHTShiRa
# Out:
#      sistolik  diastolik keterangan
# 0          75         52     rendah
# 1          73         57     rendah
# 2          84         59     rendah
# 3          71         56     rendah
# 4          88         45     rendah
# ..        ...        ...        ...
# 295       135         89     tinggi
# 296       138         98     tinggi
# 297       138         89     tinggi
# 298       126         88     tinggi
# 299       125         83     tinggi
#
# [300 rows x 3 columns]
