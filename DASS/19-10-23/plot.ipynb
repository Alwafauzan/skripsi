# %%
import os
import pandas as pd

# %%
bunga_tkr = pd.read_csv('bunga_tkr.csv',skiprows=2,sep=',')
hilmy_tkr = pd.read_csv('hilmy_tkr.csv',skiprows=2,sep=',')
ilma_tkr = pd.read_csv('ilma_tkr.csv',skiprows=2,sep=',')
maha_tkr = pd.read_csv('maha_tkr.csv',skiprows=2,sep=',')
nisa_tkr = pd.read_csv('nisa_tkr.csv',skiprows=2,sep=',')
rima_tkr = pd.read_csv('rima_tkr.csv',skiprows=2,sep=',')
winanda_tkr = pd.read_csv('winanda_tkr.csv',skiprows=2,sep=',')

# %%
bunga_tkr.plot(title='bunga_tkr')
hilmy_tkr.plot(title='hilmy_tkr')
ilma_tkr.plot(title='ilma_tkr')
maha_tkr.plot(title='maha_tkr')
nisa_tkr.plot(title='nisa_tkr')
rima_tkr.plot(title='rima_tkr')
winanda_tkr.plot(title='winanda_tkr')
# Out:
# <Axes: title={'center': 'winanda_tkr'}>

# %%
maha_tkr[2500:3000].plot()
# Out:
# <Axes: >
