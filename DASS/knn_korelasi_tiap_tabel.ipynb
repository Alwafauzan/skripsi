# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier, KNeighborsRegressor
from imblearn.over_sampling import SMOTE
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report
import os
from sklearn.preprocessing import LabelEncoder
from joblib import dump

# %%
minmax = MinMaxScaler()
sm = SMOTE(random_state=30)
le = LabelEncoder()



data = pd.read_excel('excel/bahan_knn_new/DATA_KNN_6000x1800_NEW.xlsx')
x = data[['BPM','HRV','RMSSD','SDNN','VAR','STD','SISTOL','DIASTOL','DISTANCE']]
x = minmax.fit_transform(x)
x = pd.DataFrame(x)
BPM = x[0]
HRV = x[1]
RMSSD = x[2]
SDNN = x[3]
VAR = x[4]
STD = x[5]
SISTOL = x[6]
DIASTOL = x[7]
DISTANCE = x[8]
KECEMASAN = data['KECEMASAN']
KECEMASAN_REGRESI = data['KECEMASAN_REGRESI']

# BPM_HRV = pd.concat([BPM,HRV],axis=1)
# BPM_HRV

# %%
BPM_train, BPM_test, KECEMASAN_train, KECEMASAN_test = train_test_split(BPM, KECEMASAN, test_size= 0.2, random_state=20)
HRV_train, HRV_test, KECEMASAN_train, KECEMASAN_test = train_test_split(HRV, KECEMASAN, test_size= 0.2, random_state=20)
RMSSD_train, RMSSD_test, KECEMASAN_train, KECEMASAN_test = train_test_split(RMSSD, KECEMASAN, test_size= 0.2, random_state=20)
SDNN_train, SDNN_test, KECEMASAN_train, KECEMASAN_test = train_test_split(SDNN, KECEMASAN, test_size= 0.2, random_state=20)
VAR_train, VAR_test, KECEMASAN_train, KECEMASAN_test = train_test_split(VAR, KECEMASAN, test_size= 0.2, random_state=20)
STD_train, STD_test, KECEMASAN_train, KECEMASAN_test = train_test_split(STD, KECEMASAN, test_size= 0.2, random_state=20)
SISTOL_train, SISTOL_test, KECEMASAN_train, KECEMASAN_test = train_test_split(SISTOL, KECEMASAN, test_size= 0.2, random_state=20)
DIASTOL_train, DIASTOL_test, KECEMASAN_train, KECEMASAN_test = train_test_split(DIASTOL, KECEMASAN, test_size= 0.2, random_state=20)
DISTANCE_train, DISTANCE_test, KECEMASAN_train, KECEMASAN_test = train_test_split(DISTANCE, KECEMASAN, test_size= 0.2, random_state=20)

# %%
BPM = []
HRV = []
RMSSD = []
SDNN = []
VAR = []
STD = []
SISTOL = []
DIASTOL = []
DISTANCE = []
for i in range(1,51):
    k = i
    model = KNeighborsClassifier(n_neighbors=k)
    BPM.append(model.fit(BPM_train,KECEMASAN))
    # HRV.append(model.fit(HRV,KECEMASAN))
    # RMSSD.append(model.fit(RMSSD,KECEMASAN))
    # SDNN.append(model.fit(SDNN,KECEMASAN))
    # VAR.append(model.fit(VAR,KECEMASAN))
    # STD.append(model.fit(STD,KECEMASAN))
    # SISTOL.append(model.fit(SISTOL,KECEMASAN))
    # DIASTOL.append(model.fit(DIASTOL,KECEMASAN))
    # DISTANCE.append(model.fit(DISTANCE,KECEMASAN))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# f:\repo\skripsi\DASS\knn_korelasi_tiap_tabel.ipynb Cell 5 line 1
#      <a href='vscode-notebook-cell:/f%3A/repo/skripsi/DASS/knn_korelasi_tiap_tabel.ipynb#W2sZmlsZQ%3D%3D?line=10'>11</a> k = i
#      <a href='vscode-notebook-cell:/f%3A/repo/skripsi/DASS/knn_korelasi_tiap_tabel.ipynb#W2sZmlsZQ%3D%3D?line=11'>12</a> model = KNeighborsClassifier(n_neighbors=k)
# ---> <a href='vscode-notebook-cell:/f%3A/repo/skripsi/DASS/knn_korelasi_tiap_tabel.ipynb#W2sZmlsZQ%3D%3D?line=12'>13</a> BPM.append(model.fit(BPM_train,KECEMASAN))
#      <a href='vscode-notebook-cell:/f%3A/repo/skripsi/DASS/knn_korelasi_tiap_tabel.ipynb#W2sZmlsZQ%3D%3D?line=13'>14</a> # HRV.append(model.fit(HRV,KECEMASAN))
# ...

# %%
BPM
# Out:
# [KNeighborsClassifier(n_neighbors=1),
#  KNeighborsClassifier(n_neighbors=2),
#  KNeighborsClassifier(n_neighbors=3),
#  KNeighborsClassifier(n_neighbors=4),
#  KNeighborsClassifier(),
#  KNeighborsClassifier(n_neighbors=6),
#  KNeighborsClassifier(n_neighbors=7),
#  KNeighborsClassifier(n_neighbors=8),
#  KNeighborsClassifier(n_neighbors=9),
#  KNeighborsClassifier(n_neighbors=10),
#  KNeighborsClassifier(n_neighbors=11),
#  KNeighborsClassifier(n_neighbors=12),
#  KNeighborsClassifier(n_neighbors=13),
#  KNeighborsClassifier(n_neighbors=14),
#  KNeighborsClassifier(n_neighbors=15),
#  KNeighborsClassifier(n_neighbors=16),
#  KNeighborsClassifier(n_neighbors=17),
#  KNeighborsClassifier(n_neighbors=18),
#  KNeighborsClassifier(n_neighbors=19),
#  KNeighborsClassifier(n_neighbors=20),
#  KNeighborsClassifier(n_neighbors=21),
#  KNeighborsClassifier(n_neighbors=22),
#  KNeighborsClassifier(n_neighbors=23),
#  KNeighborsClassifier(n_neighbors=24),
# ...

# %%
kecemasan = le.fit(KECEMASAN)
kecemasan = kecemasan.transform(KECEMASAN)
kecemasan = pd.DataFrame(kecemasan)

# %%
x = data[['BPM','HRV','RMSSD','SDNN','VAR','STD','SISTOL','DIASTOL','DISTANCE']]
korelasi = pd.concat([pd.DataFrame(x),kecemasan],axis=1)
korelasi.columns = ['BPM','HRV','RMSSD','SDNN','VAR','STD','SISTOL','DIASTOL','DISTANCE','KECEMASAN_REGRESI']


# korr = pd.DataFrame([
# abs(korelasi['BPM'].corr(korelasi['KECEMASAN'])),
# abs(korelasi['HRV'].corr(korelasi['KECEMASAN'])),
# abs(korelasi['RMSSD'].corr(korelasi['KECEMASAN'])),
# abs(korelasi['SDNN'].corr(korelasi['KECEMASAN'])),
# abs(korelasi['VAR'].corr(korelasi['KECEMASAN'])),
# abs(korelasi['STD'].corr(korelasi['KECEMASAN'])),
# abs(korelasi['SISTOL'].corr(korelasi['KECEMASAN'])),
# abs(korelasi['DIASTOL'].corr(korelasi['KECEMASAN'])),
# abs(korelasi['DISTANCE'].corr(korelasi['KECEMASAN']))]).mean()

# %%
korr = korelasi.corr()
plt.figure(figsize=(8, 6))
sns.heatmap(korr, annot=True, cmap='coolwarm', linewidths=.5)
plt.title('Correlation Plot')
plt.show()
